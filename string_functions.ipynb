# %% [markdown]
# #001_Python_String_capitalize()
# ##Definition:
# The capitalize() method converts the first character of the string to uppercase and the remaining characters to lowercase.
#
# Example:
#
#     text = "hello world"
#     print(text.capitalize())
#
# Output:
# Hello world
# #002_Python_String_center()
# ##Definition:
# The center() method aligns the string in the center of a specified width.
#
# Example:
#
#     text = "Python"
#     print(text.center(20))
#
# Output:
#           Python
# #003_Python_String_casefold()
# ##Definition:
# The casefold() method converts the string into lowercase.
#
# Example:
#
#     text = "HELLO"
#     print(text.casefold())
#
# Output:
# hello
# #004_Python_String_count()
# ##Definition:
# The count() method returns the number of times a substring appears in the string.
#
# Example:
#
#     text = "hello hello"
#     print(text.count("hello"))
#
# Output:
# 2
# #005_Python_String_endswith()
# ##Definition:
# The endswith() method checks whether the string ends with a specified value.
#
# Example:
#
#     text = "python.py"
#     print(text.endswith(".py"))
#
# Output:
# True
# #006_Python_String_expandtabs()
# ##Definition:
# The expandtabs() method replaces tab characters with spaces.
#
# Example:
#
#     text = "Hello\tWorld"
#     print(text.expandtabs(4))
#
# Output:
# Hello   World
# #007_Python_String_encode()
# ##Definition:
# The encode() method converts a string into encoded bytes.
#
# Example:
#
#     text = "hello"
#     print(text.encode())
#
# Output:
# b'hello'
# #008_Python_String_find()
# ##Definition:
# The find() method returns the position of the first occurrence of a substring.
#
# Example:
#
#     text = "Hello Python"
#     print(text.find("Python"))
#
# Output:
# 6
# #009_Python_String_format()
# ##Definition:
# The format() method formats the string by inserting values into placeholders.
#
# Example:
#
#     name = "Sunil"
#     print("Hello {}".format(name))
#
# Output:
# Hello Sunil
# #010_Python_String_index()
# ##Definition:
# The index() method returns the position of a substring in the string.
#
# Example:
#
#     text = "Hello Python"
#     print(text.index("Python"))
#
# Output:
# 6
# #011_Python_String_isalnum()
# ##Definition:
# The isalnum() method checks whether the string contains only alphabets and numbers.
#
# Example:
#
#     text = "Python123"
#     print(text.isalnum())
#
# Output:
# True
# #012_Python_String_isalpha()
# ##Definition:
# The isalpha() method checks whether the string contains only alphabet characters.
#
# Example:
#
#     text = "Python"
#     print(text.isalpha())
#
# Output:
# True
# #013_Python_String_isdecimal()
# ##Definition:
# The isdecimal() method checks whether the string contains only decimal characters.
#
# Example:
#
#     text = "123"
#     print(text.isdecimal())
#
# Output:
# True
# #014_Python_String_isdigit()
# ##Definition:
# The isdigit() method checks whether the string contains only digits.
#
# Example:
#
#     text = "123"
#     print(text.isdigit())
#
# Output:
# True
# #015_Python_String_isidentifier()
# ##Definition:
# The isidentifier() method checks whether the string is a valid Python identifier.
#
# Example:
#
#     text = "my_var"
#     print(text.isidentifier())
#
# Output:
# True
# #016_Python_String_islower()
# ##Definition:
# The islower() method checks whether all characters in the string are lowercase.
#
# Example:
#
#     text = "hello"
#     print(text.islower())
#
# Output:
# True
# #017_Python_String_isnumeric()
# ##Definition:
# The isnumeric() method checks whether the string contains numeric characters.
#
# Example:
#
#     text = "123"
#     print(text.isnumeric())
#
# Output:
# True
# #018_Python_String_isprintable()
# ##Definition:
# The isprintable() method checks whether all characters in the string are printable.
#
# Example:
#
#     text = "Hello"
#     print(text.isprintable())
#
# Output:
# True
# #019_Python_String_isspace()
# ##Definition:
# The isspace() method checks whether the string contains only whitespace characters.
#
# Example:
#
#     text = "   "
#     print(text.isspace())
#
# Output:
# True
# #020_Python_String_istitle()
# ##Definition:
# The istitle() method checks whether the string is in title case.
#
# Example:
#
#     text = "Hello World"
#     print(text.istitle())
#
# Output:
# True
# #021_Python_String_isupper()
# ##Definition:
# The isupper() method checks whether all characters in the string are uppercase.
#
# Example:
#
#     text = "HELLO"
#     print(text.isupper())
#
# Output:
# True
